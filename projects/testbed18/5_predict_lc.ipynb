# %% [markdown]
# # Analyze Activation Space
# ## Imports

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import rasterio
from tqdm.auto import tqdm

from tlib import tgeo, tutils
from projects.testbed18 import config, utils

# %load_ext autoreload
# %autoreload 2

# %%
asos = utils.load_asos()
files = [os.path.join(config.data_folder_tiles, file) for file in asos.map_ids]

# %% [markdown]
# ## Get Land Cover Info of Vectors

# %%
# THIS CELL IS A COPY OF 32_analyze_activation_space

# get files and arrays
files_lcs = utils.get_corresponding_files(files, 'lcs')
lcs = np.stack([tgeo.geotif.get_array(file) for file in tqdm(files_lcs)])

# get channel names (from first files sample)
with rasterio.open(files_lcs[0]) as tif:
    lc_names = tif.descriptions
print(lc_names)

# vectorize
lc_vectors = asos.vectorize_same_way(maps=lcs)
lc_vectors = {lc_names[i]: lc_vectors[:, i] for i in range(len(lc_names))}
del lcs

# plot kwargs
lc_plot_kwargs = {}
for lc_name in lc_names:
    classes = tgeo.landcover.get_params(lc=lc_name)['classes']
    colors = tgeo.landcover.get_params(lc=lc_name)['colors']
    lc_plot_kwargs[lc_name] = {'color_discrete_map': {classes[i]: colors[i] for i in range(len(classes))}}
# Out:
#   0%|          | 0/4768 [00:00<?, ?it/s]
# ('CORINE', 'MODIS_1', 'CGLS', 'GlobCover')

# %% [markdown]
# ## Assign Activation Map to Land Cover

# %%
# get group-lcs-matrix

lc_name = 'CORINE'

classes = tgeo.landcover.get_params(lc=lc_name)['classes']
groups_of_vectors = asos.predict_groups(asos.vectors)

group_lcs_matrix = np.zeros((asos.n_groups, len(classes)))
for i in tqdm(range(len(asos.vectors))):
    
    lc = lc_vectors[lc_name][i]
    if lc != 0:
        group_index = groups_of_vectors[i]
        lc_index = classes.index(lc)
        group_lcs_matrix[group_index, lc_index] += 1
        
n_vectors_in_groups = group_lcs_matrix.sum(axis=1)
group_lcs_matrix = group_lcs_matrix / n_vectors_in_groups.reshape(-1, 1)

group_lcs_matrix.shape
# Out:
# predicting groups:   0%|          | 0/981 [00:00<?, ?it/s]
#   0%|          | 0/265558 [00:00<?, ?it/s]
# (981, 44)

# %%
# get group-lc-assignment

threshold = 0.4

group_lc_percentage = group_lcs_matrix.max(1)

group_lc = group_lcs_matrix.argmax(1)
for i in range(len(group_lc)):
    if group_lc_percentage[i] > threshold:
        group_lc[i] = classes[group_lc[i]]
    else:
        group_lc[i] = -1

# %% [markdown]
# ## Plot Samples

# %%
# THIS CELL IS A COPY OF 34_analyze_samples

channel_indices = {'B2': 0, 'B3': 1, 'B4': 2, 'B5': 3, 'B6': 4, 'B7': 5, 'B8': 6, 'B8A': 7, 'B11': 8, 'B12': 9}

# files from dataset
datasets = ['test']

# get files from given dataset
fi = utils.load_file_infos()
df = fi.df
df = df[df['datasplit'].isin(datasets)]
print(f'# files: {len(df)}')
files = df.index


if config.dataset == 'anthroprotect':
    
    nearby_files_possible = True  # only if df is available
    plot_predictions = True  # only if df is available
    batch_size = 64
    
    # setup plotters
    plotters = tgeo.plotter.Plotters(plotters=[
        tgeo.plotter.S2Plotter(folder=config.data_folder_tiles, channel_indices=channel_indices),
        tgeo.plotter.LCPlotter(folder=utils.get_corresponding_folder(config.data_folder_tiles, 'lcs')),
    ])
# Out:
# # files: 2404

# %%
file = files[1100]

# predict lcs
activation_map = utils.predict_activation_maps(file)
groups_map = asos.predict_groups(activation_map)
lcs_map = np.zeros(groups_map.shape)
for i in range(groups_map.shape[1]):
    for j in range(groups_map.shape[2]):
        if groups_map[0][i][j] == -1:
            lcs_map[0][i][j] = -1
        else:
            group_index = groups_map[0][i][j]
            lcs_map[0][i][j] = group_lc[group_index]

            
# plot predicted lcs
params = tgeo.landcover.get_params(lc=lc_name)
colors, classes, framing_color = params['colors'], params['classes'], params['framing_color']
tutils.plots.plot_original_image_size(lcs_map[0], colors=colors, classes=classes, framing_color=framing_color)
plt.show()

# plot original file
plotters.plot(file)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.19it/s]
# predicting groups:   0%|          | 0/981 [00:00<?, ?it/s]
# file: anthropo_16.87133-59.52749-22_75.tif
# file: anthropo_16.87133-59.52749-22_75.tif

# %% [markdown]
# ## Correlation Matrix

# %%
import pandas as pd
df = pd.DataFrame({classes[i]: group_lcs_matrix[:, i] for i in range(len(classes))})
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /home/martin/Projekte/OGC_Testbed-18/software/venv-testbed-18/lib/python3.8/site-packages/pandas/io/formats/style.py:3555: RuntimeWarning:
#
# All-NaN slice encountered
#
# /home/martin/Projekte/OGC_Testbed-18/software/venv-testbed-18/lib/python3.8/site-packages/pandas/io/formats/style.py:3556: RuntimeWarning:
#
# All-NaN slice encountered
# <style type="text/css">
# #T_640a1_row0_col0, #T_640a1_row1_col1, #T_640a1_row2_col2, #T_640a1_row3_col3, #T_640a1_row5_col5, #T_640a1_row6_col6, #T_640a1_row7_col7, #T_640a1_row8_col8, #T_640a1_row9_col9, #T_640a1_row10_col10, #T_640a1_row11_col11, #T_640a1_row15_col15, #T_640a1_row17_col17, #T_640a1_row19_col19, #T_640a1_row20_col20, #T_640a1_row22_col22, #T_640a1_row23_col23, #T_640a1_row24_col24, #T_640a1_row25_col25, #T_640a1_row26_col26, #T_640a1_row28_col28, #T_640a1_row29_col29, #T_640a1_row30_col30, #T_640a1_row31_col31, #T_640a1_row32_col32, #T_640a1_row33_col33, #T_640a1_row34_col34, #T_640a1_row35_col35, #T_640a1_row36_col36, #T_640a1_row38_col38, #T_640a1_row39_col39, #T_640a1_row40_col40, #T_640a1_row41_col41, #T_640a1_row42_col42, #T_640a1_row43_col43 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_640a1_row0_col1, #T_640a1_row0_col22, #T_640a1_row2_col5, #T_640a1_row3_col17, #T_640a1_row5_col24, #T_640a1_row8_col1, #T_640a1_row9_col2, #T_640a1_row17_col34, #T_640a1_row29_col28, #T_640a1_row34_col43, #T_640a1_row40_col31, #T_640a1_row42_col39 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T
a1_row4_col43, #T_640a1_row5_col4, #T_640a1_row5_col12, #T_640a1_row5_col13, #T_640a1_row5_col14, #T_640a1_row5_col16, #T_640a1_row5_col18, #T_640a1_row5_col21, #T_640a1_row5_col27, #T_640a1_row5_col37, #T_640a1_row6_col4, #T_640a1_row6_col12, #T_640a1_row6_col13, #T_640a1_row6_col14, #T_640a1_row6_col16, #T_640a1_row6_col18, #T_640a1_row6_col21, #T_640a1_row6_col27, #T_640a1_row6_col37, #T_640a1_row7_col4, #T_640a1_row7_col12, #T_640a1_row7_col13, #T_640a1_row7_col14, #T_640a1_row7_col16, #T_640a1_row7_col18, #T_640a1_row7_col21, #T_640a1_row7_col27, #T_640a1_row7_col37, #T_640a1_row8_col4, #T_640a1_row8_col12, #T_640a1_row8_col13, #T_640a1_row8_col14, #T_640a1_row8_col16, #T_640a1_row8_col18, #T_640a1_row8_col21, #T_640a1_row8_col27, #T_640a1_row8_col37, #T_640a1_row9_col4, #T_640a1_row9_col12, #T_640a1_row9_col13, #T_640a1_row9_col14, #T_640a1_row9_col16, #T_640a1_row9_col18, #T_640a1_row9_col21, #T_640a1_row9_col27, #T_640a1_row9_col37, #T_640a1_row10_col4, #T_640a1_row10_col12, #T_640a1_row10_col13, #T_640a1_row10_col14, #T_640a1_row10_col16, #T_640a1_row10_col18, #T_640a1_row10_col21, #T_640a1_row10_col27, #T_640a1_row10_col37, #T_640a1_row11_col4, #T_640a1_row11_col12, #T_640a1_row11_col13, #T_640a1_row11_col14, #T_640a1_row11_col16, #T_640a1_row11_col18, #T_640a1_row11_col21, #T_640a1_row11_col27, #T_640a1_row11_col37, #T_640a1_row12_col0, #T_640a1_row12_col1, #T_640a1_row12_col2, #T_640a1_row12_col3, #T_640a1_row12_col4, #T_640a1_row12_col5, #T_640a1_row12_col6, #T_640a1_row12_col7, #T_640a1_row12_col8, #T_640a1_row12_col9, #T_640a1_row12_col10, #T_640a1_row12_col11, #T_640a1_row12_col12, #T_640a1_row12_col13, #T_640a1_row12_col14, #T_640a1_row12_col15, #T_640a1_row12_col16, #T_640a1_row12_col17, #T_640a1_row12_col18, #T_640a1_row12_col19, #T_640a1_row12_col20, #T_640a1_row12_col21, #T_640a1_row12_col22, #T_640a1_row12_col23, #T_640a1_row12_col24, #T_640a1_row12_col25, #T_640a1_row12_col26, #T_640a1_row12_col27, #T_640a1_row12_col28, #T_640a1_row12_col29, #T_640a1_row12_col30, #T_640a1_row12_col31, #T_640a1_row12_col32, #T_640a1_row12_col33, #T_640a1_row12_col34, #T_640a1_row12_col35, #T_640a1_row12_col36, #T_640a1_row12_col37, #T_640a1_row12_col38, #T_640a1_row12_col39, #T_640a1_row12_col40, #T_640a1_row12_col41, #T_640a1_row12_col42, #T_640a1_row12_col43, #T_640a1_row13_col0, #T_640a1_row13_col1,  ...
